# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#set plotting to 'ggplot' style
plt.style.use('ggplot')

# %%
# !head -5 ../titanic_dropna.csv
# Out:
# head: ../titanic_dropna.csv: No such file or directory

# %%
t = pd.read_csv('titanic_dropna.csv', index_col = 0)

# %%
t.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
t['Fare'] = np.round(t['Fare'],decimals=2)

# %%
t.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# ...

# %%
t.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# ...

# %%
copied = t.copy()

# %%
copied.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# ...

# %%
#Going to attempt separating names out here
 copied1 = pd.copied1(copied1.row.str.split(',',1).tolist()
 columns = ['LastName','FirstName'])
# Out:
#   File "<ipython-input-174-e897e35a9bc8>", line 2
#     copied1 = pd.copied1(copied1.row.str.split(',',1).tolist()
#     ^
# IndentationError: unexpected indent

# %%
"""Cabin field is an object and I am trying to convert
datatype to a string so that I can split values where there is a space. Then I want to create a new line
for each split. I am having a lot of trouble figuring out the syntax for this. Spent hours trying to figure this out :("""

copied['Cabin'] = copied['Cabin'].astype('int').astype('str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-d9d7a7788f6a> in <module>()
#       3 for each split. I am having a lot of trouble figuring out the syntax for this. Spent hours trying to figure this out :("""
#       4
# ----> 5 copied['Cabin'] = copied['Cabin'].astype('int').astype('str')
#
# /Users/macuser/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2516
#    2517         mgr = self._data.astype(
# -> 2518             dtype=dtype, copy=copy, raise_on_error=raise_on_error, **kwargs)
#    2519         return self._constructor(mgr).__finalize__(self)
#    2520
#
# /Users/macuser/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    2753
#    2754     def astype(self, dtype, **kwargs):
# ...

# %%
copied.loc['Cabin'] = copied['Cabin'].astype('str')
s = copied['Cabin'].str.split(' ').apply(Series, 1).stack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-176-34ad26a6b6f6> in <module>()
#       1 copied.loc['Cabin'] = copied['Cabin'].astype('str')
# ----> 2 s = copied['Cabin'].str.split(' ').apply(Series, 1).stack()
#
# NameError: name 'Series' is not defined

# %%
copied.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# ...

# %%
"""Finding survival rate: Survival rate = sum of "1"/ number of passengers"""
np.sum(copied['Survived'],axis=0)/len(copied.index)
# Out:
# 0.40392706872370265

# %%
copied.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# ...

# %%
copied[copied['Survived'] == 1].sort_values(by='Age', ascending=False).head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 631                 1       1
# 276                 1       1
# 484                 1       3
# 571                 1       2
# 367                 1       1
# 588                 1       1
# 269                 1       1
# 12                  1       1
# 196                 1       1
# 648                 1       1
# 880                 1       1
# 16                  1       2
# 775                 1       2
# 514                 1       1
# 497                 1       1
# 572                 1       1
# 821                 1       1
# 450                 1       1
# 592                 1       1
# 766                 1       1
#
#                                                           Name     Sex  Age  \
# PassengerId
# 631                       Barkworth, Mr. Algernon Henry Wilson    male   80
# 276                          Andrews, Miss. Kornelia Theodosia  female   63
# ...

# %%
copied[copied['Survived'] == 0].sort_values(by='Age', ascending=False).head(20)
# Out:
#              Survived  Pclass                               Name   Sex   Age  \
# PassengerId
# 852                 0       3                Svensson, Mr. Johan  male  74.0
# 494                 0       1            Artagaveytia, Mr. Ramon  male  71.0
# 97                  0       1          Goldschmidt, Mr. George B  male  71.0
# 117                 0       3               Connors, Mr. Patrick  male  70.5
# 746                 0       1       Crosby, Capt. Edward Gifford  male  70.0
# 673                 0       2        Mitchell, Mr. Henry Michael  male  70.0
# 34                  0       2              Wheadon, Mr. Edward H  male  66.0
# 281                 0       3                   Duane, Mr. Frank  male  65.0
# 457                 0       1          Millet, Mr. Francis Davis  male  65.0
# 55                  0       1     Ostby, Mr. Engelhart Cornelius  male  65.0
# 439                 0       1                  Fortune, Mr. Mark  male  64.0
# ...

# %%
copied[copied['Survived'] == 1].sort_values(by='Sex', ascending=False).head(20)
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 454                 1       1                   Goldenberg, Mr. Samuel L
# 262                 1       3          Asplund, Master. Edvin Rojj Felix
# 450                 1       1             Peuchen, Major. Arthur Godfrey
# 456                 1       3                         Jalsevac, Mr. Ivan
# 461                 1       1                        Anderson, Mr. Harry
# 485                 1       1                    Bishop, Mr. Dickinson H
# 490                 1       3      Coutts, Master. Eden Leslie "Neville"
# 510                 1       3                             Lang, Mr. Fang
# 511                 1       3                   Daly, Mr. Eugene Patrick
# 513                 1       1                  McGough, Mr. James Robert
# 544                 1       2                          Beane, Mr. Edward
# 550                 1       2             Davies, Master. John Morgan Jr
# ...

# %%
copied[copied['Survived'] == 0].sort_values(by='Sex', ascending=False).head(20)
# Out:
#              Survived  Pclass                               Name   Sex  Age  \
# PassengerId
# 1                   0       3            Braund, Mr. Owen Harris  male   22
# 537                 0       1  Butt, Major. Archibald Willingham  male   45
# 606                 0       3      Lindell, Mr. Edvard Bengtsson  male   36
# 604                 0       3          Torber, Mr. Ernst William  male   44
# 598                 0       3                Johnson, Mr. Alfred  male   49
# 596                 0       3        Van Impe, Mr. Jean Baptiste  male   36
# 595                 0       2            Chapman, Mr. John Henry  male   37
# 593                 0       3         Elsbury, Mr. William James  male   47
# 591                 0       3               Rintamaki, Mr. Matti  male   35
# 589                 0       3              Gilinski, Mr. Eliezer  male   22
# 587                 0       2            Jarvis, Mr. John Denzil  male   47
# ...

# %%
copied.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567346
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938696
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645000
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.330000

# %%
'''It looks like the survival rate for men above 50 was fairly low.
Where class is 1, folks were more likely to survive. Women were more likely to survive as well'''
# Out:
# 'It looks like the survival rate for men above 50 was fairly low.\nWhere class is 1, folks were more likely to survive. Women were more likely to survive as well'

# %%
grouped1 = copied.groupby('Sex')
grouped2 = copied.groupby('Pclass')

# %%
grouped1.describe()
# Out:
#                      Age        Fare       Parch      Pclass       SibSp  \
# Sex
# female count  259.000000  259.000000  259.000000  259.000000  259.000000
#        mean    27.745174   47.332548    0.714286    2.073359    0.644788
#        std     13.989760   61.517593    1.069045    0.843595    0.930367
#        min      0.750000    6.750000    0.000000    1.000000    0.000000
#        25%     18.000000   13.000000    0.000000    1.000000    0.000000
#        50%     27.000000   26.000000    0.000000    2.000000    0.000000
#        75%     36.000000   56.965000    1.000000    3.000000    1.000000
#        max     63.000000  512.330000    6.000000    3.000000    5.000000
# male   count  453.000000  453.000000  453.000000  453.000000  453.000000
#        mean    30.726645   27.268918    0.271523    2.335541    0.439294
#        std     14.678201   45.841890    0.651076    0.818748    0.923609
#        min      0.420000    0.000000    0.000000    1.000000    0.000000
# ...

# %%
grouped2.describe()
# Out:
#                      Age        Fare       Parch       SibSp    Survived
# Pclass
# 1      count  184.000000  184.000000  184.000000  184.000000  184.000000
#        mean    38.105543   88.048152    0.413043    0.456522    0.652174
#        std     14.778904   81.293585    0.734061    0.634406    0.477580
#        min      0.920000    0.000000    0.000000    0.000000    0.000000
#        25%     27.000000   33.890000    0.000000    0.000000    0.000000
#        50%     37.000000   67.950000    0.000000    0.000000    1.000000
#        75%     49.000000  107.040000    1.000000    1.000000    1.000000
#        max     80.000000  512.330000    4.000000    3.000000    1.000000
# 2      count  173.000000  173.000000  173.000000  173.000000  173.000000
#        mean    29.877630   21.471561    0.404624    0.427746    0.479769
#        std     14.001077   13.187353    0.705775    0.611645    0.501041
#        min      0.670000   10.500000    0.000000    0.000000    0.000000
# ...

# %%
plt.rc('figure', figsize=(10, 5))

p2 = plt.subplot(1,2,1)
grouped1[grouped1['Sex']=='female']['Survived'].value_counts().plot(
    kind='pie', labels=['Survived','Did Not Survive'],autopct='%0.0f%%',
    title='Female Survival Rate',colors=['skyblue','lightgray'],label='')

p2 = plt.subplot(1,2,2)
grouped1[grouped1['Sex']=='male']['Survived'].value_counts().plot(
    kind='pie', labels=['Did Not Survive','Survived'],autopct='%0.0f%%',
    title='Male Survival Rate',colors=['lightgray','skyblue'],label='')

####Can't get these graphs going but just by looking at the numbers, women clearly had a higher survival rate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-201-22bea91b539f> in <module>()
#       2
#       3 p2 = plt.subplot(1,2,1)
# ----> 4 grouped1[grouped1['Sex']=='female']['Survived'].value_counts().plot(
#       5     kind='pie', labels=['Survived','Did Not Survive'],autopct='%0.0f%%',
#       6     title='Female Survival Rate',colors=['skyblue','lightgray'],label='')
#
# /Users/macuser/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getitem__(self, key)
#    3379         else:
#    3380             if key not in self.obj:
# -> 3381                 raise KeyError("Column not found: %s" % key)
#    3382             # kind of a kludge
#    3383             return SeriesGroupBy(self.obj[key], selection=key,
#
# KeyError: 'Column not found: False'

# %%
#using the aggregate mean method/function I was able to see the survival rate by any age. What might be useful is 
#group these ages into categories/ranges like infants, adolescent, teen, young adult, middle age, and the elderly
grp_age = copied.groupby('Age')
grp_age['Survived'].agg(np.mean)
# Out:
# Age
# 0.42     1.000000
# 0.67     1.000000
# 0.75     1.000000
# 0.83     1.000000
# 0.92     1.000000
# 1.00     0.714286
# 2.00     0.300000
# 3.00     0.833333
# 4.00     0.700000
# 5.00     1.000000
# 6.00     0.666667
# 7.00     0.333333
# 8.00     0.500000
# 9.00     0.250000
# 10.00    0.000000
# 11.00    0.250000
# 12.00    1.000000
# 13.00    1.000000
# 14.00    0.500000
# 14.50    0.000000
# 15.00    0.800000
# 16.00    0.352941
# 17.00    0.461538
# 18.00    0.346154
# 19.00    0.360000
# 20.00    0.200000
# 20.50    0.000000
# 21.00    0.208333
# 22.00    0.407407
# 23.00    0.333333
#            ...
# 44.00    0.333333
# 45.00    0.416667
# 45.50    0.000000
# 46.00    0.000000
# 47.00    0.111111
# 48.00    0.666667
# 49.00    0.666667
# 50.00    0.500000
# 51.00    0.285714
# 52.00    0.500000
# 53.00    1.000000
# 54.00    0.375000
# 55.00    0.500000
# 55.50    0.000000
# 56.00    0.500000
# 57.00    0.000000
# 58.00    0.600000
# 59.00    0.000000
# ...

# %%
copied.groupby(pd.cut(copied['Age'],15)).agg(np.mean)
# I think 15 groupings makes more sense than 20 because these age ranges are more meaningful.
# Grouping too much may lead to unmeaningful results.
# Out:
#                    Survived    Pclass        Age     SibSp     Parch  \
# Age
# (0.34, 5.725]      0.704545  2.568182   2.503864  1.704545  1.363636
# (5.725, 11.0307]   0.333333  2.750000   8.625000  2.208333  1.541667
# (11.0307, 16.336]  0.500000  2.562500  15.109375  0.906250  0.531250
# (16.336, 21.641]   0.307692  2.538462  19.120192  0.355769  0.259615
# (21.641, 26.947]   0.373913  2.408696  23.913043  0.365217  0.304348
# (26.947, 32.252]   0.417323  2.322835  29.425197  0.291339  0.173228
# (32.252, 37.557]   0.450000  2.012500  34.812500  0.387500  0.287500
# (37.557, 42.863]   0.396552  2.086207  39.982759  0.344828  0.724138
# (42.863, 48.168]   0.326531  1.918367  45.612245  0.367347  0.469388
# (48.168, 53.473]   0.500000  1.566667  50.533333  0.466667  0.200000
# (53.473, 58.779]   0.409091  1.409091  55.704545  0.181818  0.363636
# (58.779, 64.084]   0.312500  1.562500  61.312500  0.312500  0.375000
# ...

# %%
plt.rc('figure', figsize=(15, 5))
copied['Age'].plot(kind='hist', bins=40, label='Did Not Survive', color='gray', alpha=0.8,title='Distribution of Passenger Survival Age')
copied[copied['Survived']==1]['Age'].plot(kind='hist', bins=40, label='Survived', color='skyblue', alpha=0.8)
plt.legend(loc='best')
;
# Out:
# ''

# %%
#While the frequency of survival among young adults was highest (ages 18-35), as a percentage of total passenger
#in that age group, the survival rate was still fairly low -- around the mean or lower (40% survival) in most cases
#Children, few were on board compared to other groups, had a very high percentage of survival, particularly those young
#than 10.

# %%
copied.groupby('Pclass').describe()
# Out:
#                      Age        Fare       Parch       SibSp    Survived
# Pclass
# 1      count  184.000000  184.000000  184.000000  184.000000  184.000000
#        mean    38.105543   88.048152    0.413043    0.456522    0.652174
#        std     14.778904   81.293585    0.734061    0.634406    0.477580
#        min      0.920000    0.000000    0.000000    0.000000    0.000000
#        25%     27.000000   33.890000    0.000000    0.000000    0.000000
#        50%     37.000000   67.950000    0.000000    0.000000    1.000000
#        75%     49.000000  107.040000    1.000000    1.000000    1.000000
#        max     80.000000  512.330000    4.000000    3.000000    1.000000
# 2      count  173.000000  173.000000  173.000000  173.000000  173.000000
#        mean    29.877630   21.471561    0.404624    0.427746    0.479769
#        std     14.001077   13.187353    0.705775    0.611645    0.501041
#        min      0.670000   10.500000    0.000000    0.000000    0.000000
# ...

# %%
# Set the global default size of matplotlib figures to 10 inches wide by 5 inches tall
plt.rc('figure', figsize=(15, 5))

# plot overall survival rate as pie chart
p2 = plt.subplot(1,3,1)
copied[copied['Pclass']==1]['Survived'].value_counts().plot(
    kind='pie', labels=['Survived','Did Not Survive'],autopct='%0.0f%%',
    title='Class 1 Survival Rate',colors=['skyblue','lightgray'],label='')

p2 = plt.subplot(1,3,2)
copied[copied['Pclass']==2]['Survived'].value_counts().plot(
    kind='pie', labels=['Did Not Survive','Survived'],autopct='%0.0f%%',
    title='Class 2 Survival Rate',colors=['lightgray','skyblue'],label='')

p2 = plt.subplot(1,3,3)
copied[copied['Pclass']==3]['Survived'].value_counts().plot(
    kind='pie', labels=['Did Not Survive','Survived'],autopct='%0.0f%%',
    title='Class 3 Survival Rate',colors=['lightgray','skyblue'],label='')

# %%
#We can see that class is one of the best indicators of survival with a direct correlation between higher class 
#and survival. If we wanted to predict the likelihod of survival based on class, a linear regression model might be 
# a good predictor in this case due to that direct correlation.

# %%
#I think some interesting features to add would be to look at family members aboard as this
# would deter someone from quickly saving themselves and leaving others
# Grouping by workers/crew vs passengers would be interesting as well
